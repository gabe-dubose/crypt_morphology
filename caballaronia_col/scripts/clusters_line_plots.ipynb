# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %% [markdown]
# #### Plot day~position

# %%
#read data
confidence_interval = 0.95
#day1
day1_total_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day1_total.csv')
day1_total_means = day1_anterior_data.drop(columns=['sample_id']).mean()
ci = day1_total_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day1_total_mean_ci = pd.DataFrame({
    'mean': day1_total_means,
    'upper_ci': day1_total_means + ci,
    'lower_ci': day1_total_means - ci
}).transpose()

day2_total_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day2_total.csv')
day2_total_means = day2_medial_data.drop(columns=['sample_id']).mean()
ci = day2_total_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day2_total_mean_ci = pd.DataFrame({
    'mean': day2_total_means,
    'upper_ci': day2_total_means + ci,
    'lower_ci': day2_total_means - ci
}).transpose()

day3_total_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day3_total.csv')
day3_total_means = day3_medial_data.drop(columns=['sample_id']).mean()
ci = day3_total_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day3_total_mean_ci = pd.DataFrame({
    'mean': day3_total_means,
    'upper_ci': day3_total_means + ci,
    'lower_ci': day3_total_means - ci
}).transpose()

# %%
#read data
confidence_interval = 0.95
#day2
day1_anterior_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day1_anterior_processed_data.csv')
day1_anterior_means = day1_anterior_data.drop(columns=['sample_id']).mean()
ci = day1_anterior_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day1_anterior_mean_ci = pd.DataFrame({
    'mean': day1_anterior_means,
    'upper_ci': day1_anterior_means + ci,
    'lower_ci': day1_anterior_means - ci
}).transpose()

day1_medial_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day1_medial_processed_data.csv')
day1_medial_means = day2_medial_data.drop(columns=['sample_id']).mean()
ci = day1_medial_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day1_medial_mean_ci = pd.DataFrame({
    'mean': day1_medial_means,
    'upper_ci': day1_medial_means + ci,
    'lower_ci': day1_medial_means - ci
}).transpose()

day1_posterior_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day1_posterior_processed_data.csv')
day1_posterior_means = day2_posterior_data.drop(columns=['sample_id']).mean()
ci = day1_posterior_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day1_posterior_mean_ci = pd.DataFrame({
    'mean': day2_posterior_means,
    'upper_ci': day1_posterior_means + ci,
    'lower_ci': day1_posterior_means - ci
}).transpose()

# %%
#read data
confidence_interval = 0.95
#day2
day2_anterior_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day2_anterior_processed_data.csv')
day2_anterior_means = day2_anterior_data.drop(columns=['sample_id']).mean()
ci = day2_anterior_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day2_anterior_mean_ci = pd.DataFrame({
    'mean': day2_anterior_means,
    'upper_ci': day2_anterior_means + ci,
    'lower_ci': day2_anterior_means - ci
}).transpose()

day2_medial_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day2_medial_processed_data.csv')
day2_medial_means = day2_medial_data.drop(columns=['sample_id']).mean()
ci = day2_medial_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day2_medial_mean_ci = pd.DataFrame({
    'mean': day2_medial_means,
    'upper_ci': day2_medial_means + ci,
    'lower_ci': day2_medial_means - ci
}).transpose()

day2_posterior_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day2_posterior_processed_data.csv')
day2_posterior_means = day2_posterior_data.drop(columns=['sample_id']).mean()
ci = day2_posterior_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day2_posterior_mean_ci = pd.DataFrame({
    'mean': day2_posterior_means,
    'upper_ci': day2_posterior_means + ci,
    'lower_ci': day2_posterior_means - ci
}).transpose()

# %%
#read data
confidence_interval = 0.95
#day2
day3_anterior_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day3_anterior_processed_data.csv')
day3_anterior_means = day3_anterior_data.drop(columns=['sample_id']).mean()
ci = day3_anterior_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day3_anterior_mean_ci = pd.DataFrame({
    'mean': day3_anterior_means,
    'upper_ci': day3_anterior_means + ci,
    'lower_ci': day3_anterior_means - ci
}).transpose()

day3_medial_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day3_medial_processed_data.csv')
day3_medial_means = day3_medial_data.drop(columns=['sample_id']).mean()
ci = day3_medial_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day3_medial_mean_ci = pd.DataFrame({
    'mean': day3_medial_means,
    'upper_ci': day3_medial_means + ci,
    'lower_ci': day3_medial_means - ci
}).transpose()

day3_posterior_data = pd.read_csv('/home/gabe/Desktop/caballaronia_col/processed_data/day3_posterior_processed_data.csv')
day3_posterior_means = day3_posterior_data.drop(columns=['sample_id']).mean()
ci = day3_posterior_data.drop(columns=['sample_id']).apply(lambda col: stats.sem(col) * stats.t.ppf((1 + confidence_interval) / 2, len(col) - 1))
day3_posterior_mean_ci = pd.DataFrame({
    'mean': day3_posterior_means,
    'upper_ci': day3_posterior_means + ci,
    'lower_ci': day3_posterior_means - ci
}).transpose()

# %%
#initialize plot
sns.set_style('whitegrid')
fig, [[ax1,ax2,ax3],[ax4,ax5,ax6],[ax7,ax8,ax9]] = plt.subplots(3, 3, figsize=(10, 10), sharey=True)

#day1 anterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day1_anterior_mean_ci.loc['mean'], x=x_positions, ax=ax1, color='black')
#upper CI
sns.lineplot(y=day1_anterior_mean_ci.loc['upper_ci'], x=x_positions, ax=ax1, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day1_anterior_mean_ci.loc['lower_ci'], x=x_positions, ax=ax1, color='tab:gray', linestyle='--')

#day1 medial
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day1_medial_mean_ci.loc['mean'], x=x_positions, ax=ax2, color='black')
#upper CI
sns.lineplot(y=day1_medial_mean_ci.loc['upper_ci'], x=x_positions, ax=ax2, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day1_medial_mean_ci.loc['lower_ci'], x=x_positions, ax=ax2, color='tab:gray', linestyle='--')

#day1 posterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day1_posterior_mean_ci.loc['mean'], x=x_positions, ax=ax3, color='black')
#upper CI
sns.lineplot(y=day1_posterior_mean_ci.loc['upper_ci'], x=x_positions, ax=ax3, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day1_posterior_mean_ci.loc['lower_ci'], x=x_positions, ax=ax3, color='tab:gray', linestyle='--')

ax1.set_ylabel('Day 1\nDensity')
ax1.set_title('Anterior')
ax1.set_xlabel('Relative Position')
ax2.set_xlabel('Relative Position')
ax2.set_title('Medial')
ax3.set_xlabel('Relative Position')
ax3.set_title('Posterior')

#day2 anterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day2_anterior_mean_ci.loc['mean'], x=x_positions, ax=ax4, color='black')
#upper CI
sns.lineplot(y=day2_anterior_mean_ci.loc['upper_ci'], x=x_positions, ax=ax4, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day2_anterior_mean_ci.loc['lower_ci'], x=x_positions, ax=ax4, color='tab:gray', linestyle='--')

#day2 medial
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day2_medial_mean_ci.loc['mean'], x=x_positions, ax=ax5, color='black')
#upper CI
sns.lineplot(y=day2_medial_mean_ci.loc['upper_ci'], x=x_positions, ax=ax5, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day2_medial_mean_ci.loc['lower_ci'], x=x_positions, ax=ax5, color='tab:gray', linestyle='--')

#day2 posterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day2_posterior_mean_ci.loc['mean'], x=x_positions, ax=ax6, color='black')
#upper CI
sns.lineplot(y=day2_posterior_mean_ci.loc['upper_ci'], x=x_positions, ax=ax6, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day2_posterior_mean_ci.loc['lower_ci'], x=x_positions, ax=ax6, color='tab:gray', linestyle='--')

ax4.set_ylabel('Day 2\nDensity')
ax4.set_xlabel('Relative Position')
ax5.set_xlabel('Relative Position')
ax6.set_xlabel('Relative Position')

#day3 anterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day3_anterior_mean_ci.loc['mean'], x=x_positions, ax=ax7, color='black')
#upper CI
sns.lineplot(y=day3_anterior_mean_ci.loc['upper_ci'], x=x_positions, ax=ax7, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day3_anterior_mean_ci.loc['lower_ci'], x=x_positions, ax=ax7, color='tab:gray', linestyle='--')

#day3 medial
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day3_medial_mean_ci.loc['mean'], x=x_positions, ax=ax8, color='black')
#upper CI
sns.lineplot(y=day3_medial_mean_ci.loc['upper_ci'], x=x_positions, ax=ax8, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day3_medial_mean_ci.loc['lower_ci'], x=x_positions, ax=ax8, color='tab:gray', linestyle='--')

#day3 posterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day3_posterior_mean_ci.loc['mean'], x=x_positions, ax=ax9, color='black')
#upper CI
sns.lineplot(y=day3_posterior_mean_ci.loc['upper_ci'], x=x_positions, ax=ax9, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day3_posterior_mean_ci.loc['lower_ci'], x=x_positions, ax=ax9, color='tab:gray', linestyle='--')

ax7.set_ylabel('Day 3\nDensity')
ax7.set_xlabel('Relative Position')
ax8.set_xlabel('Relative Position')
ax9.set_xlabel('Relative Position')

plt.tight_layout()
plt.savefig('/home/gabe/Desktop/caballaronia_col/figures/caballaronia_position_by_day.pdf')

# %%
#initialize plot
sns.set_style('whitegrid')
fig, [ax1,ax2,ax3] = plt.subplots(1, 3, figsize=(10, 3), sharey=True)

#day1 anterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day1_total_mean_ci.loc['mean'], x=x_positions, ax=ax1, color='black')
#upper CI
sns.lineplot(y=day1_total_mean_ci.loc['upper_ci'], x=x_positions, ax=ax1, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day1_total_mean_ci.loc['lower_ci'], x=x_positions, ax=ax1, color='tab:gray', linestyle='--')

#day1 medial
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day2_total_mean_ci.loc['mean'], x=x_positions, ax=ax2, color='black')
#upper CI
sns.lineplot(y=day2_total_mean_ci.loc['upper_ci'], x=x_positions, ax=ax2, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day2_total_mean_ci.loc['lower_ci'], x=x_positions, ax=ax2, color='tab:gray', linestyle='--')

#day1 posterior
x_positions = [i for i in range(1,25+1)]
#mean
sns.lineplot(y=day3_total_mean_ci.loc['mean'], x=x_positions, ax=ax3, color='black')
#upper CI
sns.lineplot(y=day3_total_mean_ci.loc['upper_ci'], x=x_positions, ax=ax3, color='tab:gray', linestyle='--')
#lower_ci
sns.lineplot(y=day3_total_mean_ci.loc['lower_ci'], x=x_positions, ax=ax3, color='tab:gray', linestyle='--')

ax1.set_ylabel('Density')
ax1.set_title('Day 1')
ax1.set_xlabel('Relative Position')
ax2.set_xlabel('Relative Position')
ax2.set_title('Day 2')
ax3.set_xlabel('Relative Position')
ax3.set_title('Day 3')

plt.tight_layout()
plt.savefig('/home/gabe/Desktop/caballaronia_col/figures/caballaronia_by_day.pdf')
