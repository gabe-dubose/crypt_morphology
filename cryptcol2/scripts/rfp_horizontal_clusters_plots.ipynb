# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data
data = pd.read_csv('../processed_data/horizontal_rfp_clusters.csv')

# %%
data
# Out:
#                             sample_id      idx1      idx2      idx3      idx4  \
# 0   L2_D1_GAOX-1_merge_medial_7-12-_0  0.000000  0.125354  0.363711  0.752498
# 1   L2_D1_GAOX-1_merge_medial_7-12-_1  0.064166  0.190702  0.525921  0.898093
# 2   L2_D1_GAOX-1_merge_medial_7-12-_2  0.000000  0.152772  0.540659  0.835939
# 3   L2_D1_GAOX-1_merge_medial_7-12-_3  0.000000  0.427420  1.000000  0.986602
# 4   L2_D1_GAOX-1_merge_medial_7-12-_4  0.050741  0.175642  0.494400  0.935444
# 5   L2_D1_GAOX1_merge_posterior_8-3_0  0.484008  0.546213  0.597860  0.844659
# 6   L2_D1_GAOX1_merge_posterior_8-3_1  0.170155  0.217512  0.582988  0.880303
# 7   L2_D1_GAOX1_merge_posterior_8-3_2  0.000000  0.148151  0.422694  0.771550
# 8   L2_D1_GAOX1_merge_posterior_8-3_3  0.412517  0.516421  0.788135  1.000000
# 9   L2_D1_GAOX1_merge_posterior_8-3_4  0.000000  0.142368  0.545829  0.878132
# 10  L2_D1_GAOX1_merge_anterior_8-30_0  0.000000  0.326442  0.628889  0.824500
# 11  L2_D1_GAOX1_merge_anterior_8-30_1  0.785599  0.142240  0.000000  0.142441
# 12  L2_D1_GAOX1_merge_anterior_8-30_2  0.040277  0.197829  0.603529  0.914021
# 13  L2_D1_GAOX1_merge_anterior_8-30_3  0.000000  0.196929  0.662262  0.919705
# 14  L2_D1_GAOX1_merge_anterior_8-30_4  0.000000  0.142108  0.476392  0.823592
# 15  L2_D1_GAOX1_merge_medial_9-21-2_0  0.009066  0.000000  0.048235  0.341941
# 16  L2_D1_GAOX1_merge_medial_9-21-2_1  0.000000  0.526854  0.872005  1.000000
# 17  L2_D1_GAOX1_merge_medial_9-21-2_2  1.000000  0.887630  0.972214  0.668244
# 18  L2_D1_GAOX1_merge_medial_9-21-2_3  0.164169  0.029173  0.000000  0.126317
# 19  L2_D1_GAOX1_merge_medial_9-21-2_4  0.000000  0.484959  1.000000  0.767474
# 20  L2_D1_GAOX1_merge_anterior_7-14_0  0.706058  0.721118  1.000000  0.397538
# 21  L2_D1_GAOX1_merge_anterior_7-14_1  0.000000  0.172266  0.335030  0.323627
# 22  L2_D1_GAOX1_merge_anterior_7-14_2  0.001657  0.035942  0.346116  0.079415
# 23  L2_D1_GAOX1_merge_anterior_7-14_3  0.001725  0.187343  1.000000  0.847886
# 24  L2_D1_GAOX-1_merge_anterior_7-1_0  0.488800  0.725611  0.524740  0.262473
# 25  L2_D1_GAOX-1_merge_anterior_7-1_1  0.000000  0.508507  0.830086  1.000000
# 26  L2_D1_GAOX-1_merge_anterior_7-1_2  0.000000  0.409472  0.577650  0.659243
# 27  L2_D1_GAOX-1_merge_anterior_7-1_3  0.375954  0.348201  0.277122  0.352584
# 28  L2_D1_GAOX-1_merge_anterior_7-1_4  0.812918  0.943441  1.000000  0.969937
# 29  L2_D1_GAOX1_merge_anterior_9-21_0  0.335249  0.366535  0.471576  0.720153
# 30  L2_D1_GAOX1_merge_anterior_9-21_1  0.125458  0.448925  0.708628  0.769420
# 31  L2_D1_GAOX1_merge_anterior_9-21_2  0.250761  0.606373  0.949217  0.974366
# 31  1.000000  0.933018  0.849244  0.375067  0.000000  0.049292
# 32  1.000000  0.711520  0.195715  0.000000  0.008015  0.078456
# 33  0.747513  1.000000  0.993336  0.610120  0.254990  0.166041
# 34  1.000000  0.984689  0.922519  0.712623  0.210359  0.000000
# 35  0.814580  0.961271  1.000000  0.891493  0.531210  0.140757
# 36  0.305225  0.547605  0.821852  1.000000  0.741970  0.381649
# 37  0.998699  1.000000  0.842254  0.565224  0.196997  0.000000
# 38  0.249978  0.000000  0.238946  0.164552  0.079615  0.868042
# 39  0.919418  0.751674  0.647490  0.356829  0.092232  0.000000
# 40  0.976602  0.831863  0.659107  0.399343  0.225666  0.000000
# 41  0.902603  0.810305  0.654147  0.470881  0.059625  0.000000
# 42  0.908389  0.834356  0.706140  0.426819  0.089088  0.000000
# 43  1.000000  0.892770  0.604444  0.238088  0.000000  0.078440
#
#     cutree.rfp.clusters..h...1.85.
# 0                                1
# 1                                2
# 2                                1
# 3                                3
# 4                                2
# 5                                2
# 6                                1
# 7                                1
# 8                                2
# 9                                1
# 10                               1
# 11                               4
# 12                               1
# 13                               1
# 14                               1
# 15                               1
# 16                               2
# 17                               3
# 18                               1
# 19                               1
# 20                               3
# 21                               1
# 22                               1
# 23                               3
# 24                               3
# 25                               4
# 26                               4
# 27                               3
# 28                               2
# 29                               1
# 30                               1
# 31                               2
# 32                               2
# 33                               1
# 34                               1
# 35                               1
# 36                               4
# 37                               1
# 38                               3
# 39                               2
# 40                               2
# 41                               2
# 42                               2
# 43                               2

# %%
sns.set_style('whitegrid')
fig, [ax1,ax2,ax3,ax4] = plt.subplots(1, 4, figsize=(16, 4), sharey=True)

value_cols = ['idx1', 'idx2', 'idx3', 'idx4', 'idx5', 'idx6', 'idx7', 'idx8', 'idx9', 'idx10']

#cluster1
cluster_1 = data.loc[data['cutree.rfp.clusters..h...1.85.'] == 1]
clust1_samples = list(cluster_1['sample_id'])
clust1_data = cluster_1[value_cols]
for index, row in clust1_data.iterrows():
    values = list(row)
    sns.lineplot(values, ax=ax1, color='tab:gray', alpha=0.5)

cluster_2 = data.loc[data['cutree.rfp.clusters..h...1.85.'] == 2]
clust2_samples = list(cluster_2['sample_id'])
clust2_data = cluster_2[value_cols]
for index, row in clust2_data.iterrows():
    values = list(row)
    sns.lineplot(values, ax=ax2, color='tab:gray', alpha=0.8)

cluster_3 = data.loc[data['cutree.rfp.clusters..h...1.85.'] == 3]
clust3_samples = list(cluster_3['sample_id'])
clust3_data = cluster_3[value_cols]
for index, row in clust3_data.iterrows():
    values = list(row)
    sns.lineplot(values, ax=ax3, color='tab:gray', alpha=0.8)


cluster_4 = data.loc[data['cutree.rfp.clusters..h...1.85.'] == 4]
clust4_samples = list(cluster_4['sample_id'])
clust4_data = cluster_4[value_cols]
for index, row in clust4_data.iterrows():
    values = list(row)
    sns.lineplot(values, ax=ax4, color='tab:gray', alpha=0.8)


#add mean value lines
sns.lineplot(list(clust1_data.mean(axis=0)), ax=ax1, color='black', linewidth=3)
sns.lineplot(list(clust2_data.mean(axis=0)), ax=ax2, color='black', linewidth=3)
sns.lineplot(list(clust3_data.mean(axis=0)), ax=ax3, color='black', linewidth=3)
sns.lineplot(list(clust4_data.mean(axis=0)), ax=ax4, color='black', linewidth=3)

plt.savefig('../figures/rfp_clusters.pdf')
